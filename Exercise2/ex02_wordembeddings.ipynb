# %%
import csv
import pandas as pd
import numpy as np
import string
import re

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import IterableDataset, DataLoader, Dataset

# %%
hotel_reviews = pd.read_csv(r"C:\Users\Damja\OneDrive\Damjan\HS22\NLP UZH\Exercise2\tripadvisor_hotel_reviews.csv")
scifi_pth = r"C:\Users\Damja\OneDrive\Damjan\HS22\NLP UZH\Exercise2\scifi.txt"

# %%
with open(path, 'r', encoding='utf-8') as foo:
    f = foo.readline()  # it is only '1' line

scifi = f.split()

# %%
CONTEXT_SIZE = 2  # 2 words to the left, 2 to the right

def make_context_vector(context, word_to_ix):
    idxs = [word_to_ix[w] for w in context]
    return torch.tensor(idxs, dtype=torch.long)

# %% [markdown]
# ### Preprocessing the hotel reviews data
# For that, we create a class which contains all the methods we need for preprocessing the data.

# %%
class Preprocessing():

    def __init__(self, full_dataset):
        self.full_dataset = full_dataset
        self.word_to_ix = {}
        self.ix_to_word = {}
        self.context_dataset = []
        self.vocab_size = None
    
    def create_context_vocab(self, input_txt):
        """
        Takes preprocessed lists of words and creates a context dataset
        At the same time it creates the word_to_ix and ix_to_word dictionaries for lookup
        """

        for i in range(2, len(input_txt) - 2):
            context = [input_txt[i - 2], input_txt[i - 1],
                       input_txt[i + 1], input_txt[i + 2]]
            target = input_txt[i]
            self.context_dataset.append((context, target))

        # adding words to our vocabulary list    
        input_txt = set(input_txt)
        # get the current n
        for el in input_txt:
            if el not in self.word_to_ix:
                self.word_to_ix[el] = len(self.word_to_ix)
    
    def apply_create_context_vocab(self):
        """
        Applys the create context fct to every row
        """
        for row in range(self.full_dataset.shape[0]):
            self.create_context_vocab(self.full_dataset['Review'][row].split())
        self.ix_to_word = dict((v, k) for k, v in self.word_to_ix.items())
        
        
    def convert_lowercase(self, x):
        x = x.lower()
        return x
        
    def remove_emoji(self, x):
        emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               "]+", flags=re.UNICODE)
        return emoji_pattern.sub(r'', x)
        
    exclude = string.punctuation
    
    def remove_punc(self, x):
        exclude = string.punctuation
        return x.translate(str.maketrans('', '', exclude))
    
    def remove_special_chars(self, x):
        x = re.sub('[^A-Za-z0-9]+', ' ', x)
        return x

    def remove_one_letter_words(self, x):
        x = re.sub(r'(?:^| )\w(?:$| )', ' ', x).strip()
        return x
    
    # default is to apply all these preprocessing steps
    def apply_preprocessing(self,
                            lowercase=True,
                            remove_emoji=True,
                            remove_punc=True,
                            remove_special_chars=True,
                            remove_one_letter_words=True):
        if lowercase:
            self.full_dataset['Review'] = self.full_dataset['Review'].apply(self.convert_lowercase)
        if remove_emoji:
            self.full_dataset['Review'] = self.full_dataset['Review'].apply(self.remove_emoji)
        if remove_punc:
            self.full_dataset['Review'] = self.full_dataset['Review'].apply(self.remove_punc)
        if remove_special_chars:
            self.full_dataset['Review'] = self.full_dataset['Review'].apply(self.remove_special_chars)
        if remove_one_letter_words:
            self.full_dataset['Review'] = self.full_dataset['Review'].apply(self.remove_one_letter_words)

# %%
my_data = Preprocessing(hotel_reviews)

# %%
#my_data.apply_preprocessing()

# %%
my_data.full_dataset
# Out:
#                                                   Review  Rating
# 0      nice hotel expensive parking got good deal sta...       4
# 1      ok nothing special charge diamond member hilto...       2
# 2      nice rooms not experience hotel monaco seattle...       3
# 3      unique great stay wonderful time hotel monaco ...       5
# 4      great stay great stay went seahawk game awesom...       5
# ...                                                  ...     ...
# 20486  best kept secret 3rd time staying charm not 5s...       5
# 20487  great location price view hotel great quick pl...       4
# 20488  ok just looks nice modern outside desk staff n...       2
# 20489  hotel theft ruined vacation hotel opened sept ...       1
# 20490  people talking ca nt believe excellent ratings...       2
#
# [20491 rows x 2 columns]

# %%
my_data.apply_create_context_vocab()

# %%
len(my_data.word_to_ix)
# Out:
# 80380

# %%
(my_data.context_dataset)
# Out:
# [(['nice', 'hotel', 'parking', 'got'], 'expensive'),
#  (['hotel', 'expensive', 'got', 'good'], 'parking'),
#  (['expensive', 'parking', 'good', 'deal'], 'got'),
#  (['parking', 'got', 'deal', 'stay'], 'good'),
#  (['got', 'good', 'stay', 'hotel'], 'deal'),
#  (['good', 'deal', 'hotel', 'anniversary'], 'stay'),
#  (['deal', 'stay', 'anniversary', 'arrived'], 'hotel'),
#  (['stay', 'hotel', 'arrived', 'late'], 'anniversary'),
#  (['hotel', 'anniversary', 'late', 'evening'], 'arrived'),
#  (['anniversary', 'arrived', 'evening', 'took'], 'late'),
#  (['arrived', 'late', 'took', 'advice'], 'evening'),
#  (['late', 'evening', 'advice', 'previous'], 'took'),
#  (['evening', 'took', 'previous', 'reviews'], 'advice'),
#  (['took', 'advice', 'reviews', 'did'], 'previous'),
#  (['advice', 'previous', 'did', 'valet'], 'reviews'),
#  (['previous', 'reviews', 'valet', 'parking'], 'did'),
#  (['reviews', 'did', 'parking', 'check'], 'valet'),
#  (['did', 'valet', 'check', 'quick'], 'parking'),
#  (['valet', 'parking', 'quick', 'easy'], 'check'),
#  (['parking', 'check', 'easy', 'little'], 'quick'),
#  (['check', 'quick', 'little', 'disappointed'], 'easy'),
#  (['quick', 'easy', 'disappointed', 'nonexistent'], 'little'),
#  (['easy', 'little', 'nonexistent', 'view'], 'disappointed'),
#  (['little', 'disappointed', 'view', 'room'], 'nonexistent'),
#  (['disappointed', 'nonexistent', 'room', 'room'], 'view'),
#  (['nonexistent', 'view', 'room', 'clean'], 'room'),
#  (['view', 'room', 'clean', 'nice'], 'room'),
#  (['room', 'room', 'nice', 'size'], 'clean'),
#  (['room', 'clean', 'size', 'bed'], 'nice'),
#  (['clean', 'nice', 'bed', 'comfortable'], 'size'),
#  (['nice', 'size', 'comfortable', 'woke'], 'bed'),
#  (['size', 'bed', 'woke', 'stiff'], 'comfortable'),
#  (['bed', 'comfortable', 'stiff', 'neck'], 'woke'),
#  (['comfortable', 'woke', 'neck', 'high'], 'stiff'),
#  (['woke', 'stiff', 'high', 'pillows'], 'neck'),
#  (['stiff', 'neck', 'pillows', 'not'], 'high'),
#  (['neck', 'high', 'not', 'soundproof'], 'pillows'),
#  (['high', 'pillows', 'soundproof', 'like'], 'not'),
#  (['pillows', 'not', 'like', 'heard'], 'soundproof'),
#  (['not', 'soundproof', 'heard', 'music'], 'like'),
#  (['soundproof', 'like', 'music', 'room'], 'heard'),
#  (['like', 'heard', 'room', 'night'], 'music'),
#  (['heard', 'music', 'night', 'morning'], 'room'),
#  (['music', 'room', 'morning', 'loud'], 'night'),
#  (['room', 'night', 'loud', 'bangs'], 'morning'),
#  (['night', 'morning', 'bangs', 'doors'], 'loud'),
#  (['morning', 'loud', 'doors', 'opening'], 'bangs'),
#  (['loud', 'bangs', 'opening', 'closing'], 'doors'),
#  (['bangs', 'doors', 'closing', 'hear'], 'opening'),
#  (['doors', 'opening', 'hear', 'people'], 'closing'),
#  (['opening', 'closing', 'people', 'talking'], 'hear'),
#  (['closing', 'hear', 'talking', 'hallway'], 'people'),
#  (['hear', 'people', 'hallway', 'maybe'], 'talking'),
#  (['people', 'talking', 'maybe', 'just'], 'hallway'),
#  (['talking', 'hallway', 'just', 'noisy'], 'maybe'),
#  (['hallway', 'maybe', 'noisy', 'neighbors'], 'just'),
#  (['maybe', 'just', 'neighbors', 'aveda'], 'noisy'),
#  (['just', 'noisy', 'aveda', 'bath'], 'neighbors'),
#  (['noisy', 'neighbors', 'bath', 'products'], 'aveda'),
#  (['neighbors', 'aveda', 'products', 'nice'], 'bath'),
#  (['aveda', 'bath', 'nice', 'did'], 'products'),
#  (['bath', 'products', 'did', 'not'], 'nice'),
#  (['products', 'nice', 'not', 'goldfish'], 'did'),
#  (['nice', 'did', 'goldfish', 'stay'], 'not'),
#  (['did', 'not', 'stay', 'nice'], 'goldfish'),
#  (['not', 'goldfish', 'nice', 'touch'], 'stay'),
#  (['goldfish', 'stay', 'touch', 'taken'], 'nice'),
#  (['stay', 'nice', 'taken', 'advantage'], 'touch'),
#  (['nice', 'touch', 'advantage', 'staying'], 'taken'),
#  (['touch', 'taken', 'staying', 'longer'], 'advantage'),
#  (['taken', 'advantage', 'longer', 'location'], 'staying'),
#  (['advantage', 'staying', 'location', 'great'], 'longer'),
#  (['staying', 'longer', 'great', 'walking'], 'location'),
#  (['longer', 'location', 'walking', 'distance'], 'great'),
#  (['location', 'great', 'distance', 'shopping'], 'walking'),
#  (['great', 'walking', 'shopping', 'overall'], 'distance'),
#  (['walking', 'distance', 'overall', 'nice'], 'shopping'),
#  (['distance', 'shopping', 'nice', 'experience'], 'overall'),
#  (['shopping', 'overall', 'experience', 'having'], 'nice'),
#  (['overall', 'nice', 'having', 'pay'], 'experience'),
#  (['nice', 'experience', 'pay', '40'], 'having'),
#  (['experience', 'having', '40', 'parking'], 'pay'),
#  (['having', 'pay', 'parking', 'night'], '40'),
#  (['ok', 'nothing', 'charge', 'diamond'], 'special'),
#  (['nothing', 'special', 'diamond', 'member'], 'charge'),
#  (['special', 'charge', 'member', 'hilton'], 'diamond'),
#  (['charge', 'diamond', 'hilton', 'decided'], 'member'),
#  (['diamond', 'member', 'decided', 'chain'], 'hilton'),
#  (['member', 'hilton', 'chain', 'shot'], 'decided'),
#  (['hilton', 'decided', 'shot', '20th'], 'chain'),
#  (['decided', 'chain', '20th', 'anniversary'], 'shot'),
#  (['chain', 'shot', 'anniversary', 'seattle'], '20th'),
#  (['shot', '20th', 'seattle', 'start'], 'anniversary'),
#  (['20th', 'anniversary', 'start', 'booked'], 'seattle'),
#  (['anniversary', 'seattle', 'booked', 'suite'], 'start'),
#  (['seattle', 'start', 'suite', 'paid'], 'booked'),
#  (['start', 'booked', 'paid', 'extra'], 'suite'),
#  (['booked', 'suite', 'extra', 'website'], 'paid'),
#  (['suite', 'paid', 'website', 'description'], 'extra'),
#  (['paid', 'extra', 'description', 'not'], 'website'),
#  (['extra', 'website', 'not', 'suite'], 'description'),
#  (['website', 'description', 'suite', 'bedroom'], 'not'),
#  (['description', 'not', 'bedroom', 'bathroom'], 'suite'),
#  (['not', 'suite', 'bathroom', 'standard'], 'bedroom'),
#  (['suite', 'bedroom', 'standard', 'hotel'], 'bathroom'),
#  (['bedroom', 'bathroom', 'hotel', 'room'], 'standard'),
#  (['bathroom', 'standard', 'room', 'took'], 'hotel'),
#  (['standard', 'hotel', 'took', 'printed'], 'room'),
#  (['hotel', 'room', 'printed', 'reservation'], 'took'),
#  (['room', 'took', 'reservation', 'desk'], 'printed'),
#  (['took', 'printed', 'desk', 'showed'], 'reservation'),
#  (['printed', 'reservation', 'showed', 'said'], 'desk'),
#  (['reservation', 'desk', 'said', 'things'], 'showed'),
#  (['desk', 'showed', 'things', 'like'], 'said'),
#  (['showed', 'said', 'like', 'tv'], 'things'),
#  (['said', 'things', 'tv', 'couch'], 'like'),
#  (['things', 'like', 'couch', 'ect'], 'tv'),
#  (['like', 'tv', 'ect', 'desk'], 'couch'),
#  (['tv', 'couch', 'desk', 'clerk'], 'ect'),
#  (['couch', 'ect', 'clerk', 'told'], 'desk'),
#  (['ect', 'desk', 'told', 'oh'], 'clerk'),
#  (['desk', 'clerk', 'oh', 'mixed'], 'told'),
#  (['clerk', 'told', 'mixed', 'suites'], 'oh'),
#  (['told', 'oh', 'suites', 'description'], 'mixed'),
#  (['oh', 'mixed', 'description', 'kimpton'], 'suites'),
#  (['mixed', 'suites', 'kimpton', 'website'], 'description'),
#  (['suites', 'description', 'website', 'sorry'], 'kimpton'),
#  (['description', 'kimpton', 'sorry', 'free'], 'website'),
#  (['kimpton', 'website', 'free', 'breakfast'], 'sorry'),
#  (['website', 'sorry', 'breakfast', 'got'], 'free'),
#  (['sorry', 'free', 'got', 'kidding'], 'breakfast'),
#  (['free', 'breakfast', 'kidding', 'embassy'], 'got'),
#  (['breakfast', 'got', 'embassy', 'suits'], 'kidding'),
#  (['got', 'kidding', 'suits', 'sitting'], 'embassy'),
#  (['kidding', 'embassy', 'sitting', 'room'], 'suits'),
#  (['embassy', 'suits', 'room', 'bathroom'], 'sitting'),
#  (['suits', 'sitting', 'bathroom', 'bedroom'], 'room'),
#  (['sitting', 'room', 'bedroom', 'unlike'], 'bathroom'),
#  (['room', 'bathroom', 'unlike', 'kimpton'], 'bedroom'),
#  (['bathroom', 'bedroom', 'kimpton', 'calls'], 'unlike'),
#  (['bedroom', 'unlike', 'calls', 'suite'], 'kimpton'),
#  (['unlike', 'kimpton', 'suite', 'day'], 'calls'),
#  (['kimpton', 'calls', 'day', 'stay'], 'suite'),
#  (['calls', 'suite', 'stay', 'offer'], 'day'),
#  (['suite', 'day', 'offer', 'correct'], 'stay'),
#  (['day', 'stay', 'correct', 'false'], 'offer'),
#  (['stay', 'offer', 'false', 'advertising'], 'correct'),
#  (['offer', 'correct', 'advertising', 'send'], 'false'),
#  (['correct', 'false', 'send', 'kimpton'], 'advertising'),
#  (['false', 'advertising', 'kimpton', 'preferred'], 'send'),
#  (['advertising', 'send', 'preferred', 'guest'], 'kimpton'),
#  (['send', 'kimpton', 'guest', 'website'], 'preferred'),
#  (['kimpton', 'preferred', 'website', 'email'], 'guest'),
#  (['preferred', 'guest', 'email', 'asking'], 'website'),
#  (['guest', 'website', 'asking', 'failure'], 'email'),
#  (['website', 'email', 'failure', 'provide'], 'asking'),
#  (['email', 'asking', 'provide', 'suite'], 'failure'),
#  (['asking', 'failure', 'suite', 'advertised'], 'provide'),
#  (['failure', 'provide', 'advertised', 'website'], 'suite'),
#  (['provide', 'suite', 'website', 'reservation'], 'advertised'),
#  (['suite', 'advertised', 'reservation', 'description'], 'website'),
#  (['advertised', 'website', 'description', 'furnished'], 'reservation'),
#  (['website', 'reservation', 'furnished', 'hard'], 'description'),
#  (['reservation', 'description', 'hard', 'copy'], 'furnished'),
#  (['description', 'furnished', 'copy', 'reservation'], 'hard'),
#  (['furnished', 'hard', 'reservation', 'printout'], 'copy'),
#  (['hard', 'copy', 'printout', 'website'], 'reservation'),
#  (['copy', 'reservation', 'website', 'desk'], 'printout'),
#  (['reservation', 'printout', 'desk', 'manager'], 'website'),
#  (['printout', 'website', 'manager', 'duty'], 'desk'),
#  (['website', 'desk', 'duty', 'did'], 'manager'),
#  (['desk', 'manager', 'did', 'not'], 'duty'),
#  (['manager', 'duty', 'not', 'reply'], 'did'),
#  (['duty', 'did', 'reply', 'solution'], 'not'),
#  (['did', 'not', 'solution', 'send'], 'reply'),
#  (['not', 'reply', 'send', 'email'], 'solution'),
#  (['reply', 'solution', 'email', 'trip'], 'send'),
#  (['solution', 'send', 'trip', 'guest'], 'email'),
#  (['send', 'email', 'guest', 'survey'], 'trip'),
#  (['email', 'trip', 'survey', 'did'], 'guest'),
#  (['trip', 'guest', 'did', 'not'], 'survey'),
#  (['guest', 'survey', 'not', 'follow'], 'did'),
#  (['survey', 'did', 'follow', 'email'], 'not'),
#  (['did', 'not', 'email', 'mail'], 'follow'),
#  (['not', 'follow', 'mail', 'guess'], 'email'),
#  (['follow', 'email', 'guess', 'tell'], 'mail'),
#  (['email', 'mail', 'tell', 'concerned'], 'guess'),
#  (['mail', 'guess', 'concerned', 'guestthe'], 'tell'),
#  (['guess', 'tell', 'guestthe', 'staff'], 'concerned'),
#  (['tell', 'concerned', 'staff', 'ranged'], 'guestthe'),
#  (['concerned', 'guestthe', 'ranged', 'indifferent'], 'staff'),
#  (['guestthe', 'staff', 'indifferent', 'not'], 'ranged'),
#  (['staff', 'ranged', 'not', 'helpful'], 'indifferent'),
#  (['ranged', 'indifferent', 'helpful', 'asked'], 'not'),
#  (['indifferent', 'not', 'asked', 'desk'], 'helpful'),
#  (['not', 'helpful', 'desk', 'good'], 'asked'),
#  (['helpful', 'asked', 'good', 'breakfast'], 'desk'),
#  (['asked', 'desk', 'breakfast', 'spots'], 'good'),
#  (['desk', 'good', 'spots', 'neighborhood'], 'breakfast'),
#  (['good', 'breakfast', 'neighborhood', 'hood'], 'spots'),
#  (['breakfast', 'spots', 'hood', 'told'], 'neighborhood'),
#  (['spots', 'neighborhood', 'told', 'no'], 'hood'),
#  (['neighborhood', 'hood', 'no', 'hotels'], 'told'),
#  (['hood', 'told', 'hotels', 'gee'], 'no'),
#  (['told', 'no', 'gee', 'best'], 'hotels'),
#  (['no', 'hotels', 'best', 'breakfast'], 'gee'),
#  (['hotels', 'gee', 'breakfast', 'spots'], 'best'),
#  (['gee', 'best', 'spots', 'seattle'], 'breakfast'),
#  (['best', 'breakfast', 'seattle', '12'], 'spots'),
#  (['breakfast', 'spots', '12', 'block'], 'seattle'),
#  (['spots', 'seattle', 'block', 'away'], '12'),
#  (['seattle', '12', 'away', 'convenient'], 'block'),
#  (['12', 'block', 'convenient', 'hotel'], 'away'),
#  (['block', 'away', 'hotel', 'does'], 'convenient'),
#  (['away', 'convenient', 'does', 'not'], 'hotel'),
#  (['convenient', 'hotel', 'not', 'know'], 'does'),
#  (['hotel', 'does', 'know', 'exist'], 'not'),
#  (['does', 'not', 'exist', 'arrived'], 'know'),
#  (['not', 'know', 'arrived', 'late'], 'exist'),
#  (['know', 'exist', 'late', 'night'], 'arrived'),
#  (['exist', 'arrived', 'night', '11'], 'late'),
#  (['arrived', 'late', '11', 'pm'], 'night'),
#  (['late', 'night', 'pm', 'inside'], '11'),
#  (['night', '11', 'inside', 'run'], 'pm'),
#  (['11', 'pm', 'run', 'bellman'], 'inside'),
#  (['pm', 'inside', 'bellman', 'busy'], 'run'),
#  (['inside', 'run', 'busy', 'chating'], 'bellman'),
#  (['run', 'bellman', 'chating', 'cell'], 'busy'),
#  (['bellman', 'busy', 'cell', 'phone'], 'chating'),
#  (['busy', 'chating', 'phone', 'help'], 'cell'),
#  (['chating', 'cell', 'help', 'bagsprior'], 'phone'),
#  (['cell', 'phone', 'bagsprior', 'arrival'], 'help'),
#  (['phone', 'help', 'arrival', 'emailed'], 'bagsprior'),
#  (['help', 'bagsprior', 'emailed', 'hotel'], 'arrival'),
#  (['bagsprior', 'arrival', 'hotel', 'inform'], 'emailed'),
#  (['arrival', 'emailed', 'inform', '20th'], 'hotel'),
#  (['emailed', 'hotel', '20th', 'anniversary'], 'inform'),
#  (['hotel', 'inform', 'anniversary', 'half'], '20th'),
#  (['inform', '20th', 'half', 'really'], 'anniversary'),
#  (['20th', 'anniversary', 'really', 'picky'], 'half'),
#  (['anniversary', 'half', 'picky', 'wanted'], 'really'),
#  (['half', 'really', 'wanted', 'make'], 'picky'),
#  (['really', 'picky', 'make', 'sure'], 'wanted'),
#  (['picky', 'wanted', 'sure', 'good'], 'make'),
#  (['wanted', 'make', 'good', 'got'], 'sure'),
#  (['make', 'sure', 'got', 'nice'], 'good'),
#  (['sure', 'good', 'nice', 'email'], 'got'),
#  (['good', 'got', 'email', 'saying'], 'nice'),
#  (['got', 'nice', 'saying', 'like'], 'email'),
#  (['nice', 'email', 'like', 'deliver'], 'saying'),
#  (['email', 'saying', 'deliver', 'bottle'], 'like'),
#  (['saying', 'like', 'bottle', 'champagne'], 'deliver'),
#  (['like', 'deliver', 'champagne', 'chocolate'], 'bottle'),
#  (['deliver', 'bottle', 'chocolate', 'covered'], 'champagne'),
#  (['bottle', 'champagne', 'covered', 'strawberries'], 'chocolate'),
#  (['champagne', 'chocolate', 'strawberries', 'room'], 'covered'),
#  (['chocolate', 'covered', 'room', 'arrival'], 'strawberries'),
#  (['covered', 'strawberries', 'arrival', 'celebrate'], 'room'),
#  (['strawberries', 'room', 'celebrate', 'told'], 'arrival'),
#  (['room', 'arrival', 'told', 'needed'], 'celebrate'),
#  (['arrival', 'celebrate', 'needed', 'foam'], 'told'),
#  (['celebrate', 'told', 'foam', 'pillows'], 'needed'),
#  (['told', 'needed', 'pillows', 'arrival'], 'foam'),
#  (['needed', 'foam', 'arrival', 'no'], 'pillows'),
#  (['foam', 'pillows', 'no', 'champagne'], 'arrival'),
#  (['pillows', 'arrival', 'champagne', 'strawberries'], 'no'),
#  (['arrival', 'no', 'strawberries', 'no'], 'champagne'),
#  (['no', 'champagne', 'no', 'foam'], 'strawberries'),
#  (['champagne', 'strawberries', 'foam', 'pillows'], 'no'),
#  (['strawberries', 'no', 'pillows', 'great'], 'foam'),
#  (['no', 'foam', 'great', 'room'], 'pillows'),
#  (['foam', 'pillows', 'room', 'view'], 'great'),
#  (['pillows', 'great', 'view', 'alley'], 'room'),
#  (['great', 'room', 'alley', 'high'], 'view'),
#  (['room', 'view', 'high', 'rise'], 'alley'),
#  (['view', 'alley', 'rise', 'building'], 'high'),
#  (['alley', 'high', 'building', 'good'], 'rise'),
#  (['high', 'rise', 'good', 'not'], 'building'),
#  (['rise', 'building', 'not', 'better'], 'good'),
#  (['building', 'good', 'better', 'housekeeping'], 'not'),
#  (['good', 'not', 'housekeeping', 'staff'], 'better'),
#  (['not', 'better', 'staff', 'cleaner'], 'housekeeping'),
#  (['better', 'housekeeping', 'cleaner', 'room'], 'staff'),
#  (['housekeeping', 'staff', 'room', 'property'], 'cleaner'),
#  (['staff', 'cleaner', 'property', 'impressed'], 'room'),
#  (['cleaner', 'room', 'impressed', 'left'], 'property'),
#  (['room', 'property', 'left', 'morning'], 'impressed'),
#  (['property', 'impressed', 'morning', 'shopping'], 'left'),
#  (['impressed', 'left', 'shopping', 'room'], 'morning'),
#  (['left', 'morning', 'room', 'got'], 'shopping'),
#  (['morning', 'shopping', 'got', 'short'], 'room'),
#  (['shopping', 'room', 'short', 'trips'], 'got'),
#  (['room', 'got', 'trips', 'hours'], 'short'),
#  (['got', 'short', 'hours', 'beds'], 'trips'),
#  (['short', 'trips', 'beds', 'comfortablenot'], 'hours'),
#  (['trips', 'hours', 'comfortablenot', 'good'], 'beds'),
#  (['hours', 'beds', 'good', 'acheat'], 'comfortablenot'),
#  (['beds', 'comfortablenot', 'acheat', 'control'], 'good'),
#  (['comfortablenot', 'good', 'control', 'x'], 'acheat'),
#  (['good', 'acheat', 'x', 'inch'], 'control'),
#  (['acheat', 'control', 'inch', 'screen'], 'x'),
#  (['control', 'x', 'screen', 'bring'], 'inch'),
#  (['x', 'inch', 'bring', 'green'], 'screen'),
#  (['inch', 'screen', 'green', 'shine'], 'bring'),
#  (['screen', 'bring', 'shine', 'directly'], 'green'),
#  (['bring', 'green', 'directly', 'eyes'], 'shine'),
#  (['green', 'shine', 'eyes', 'night'], 'directly'),
#  (['shine', 'directly', 'night', 'light'], 'eyes'),
#  (['directly', 'eyes', 'light', 'sensitive'], 'night'),
#  (['eyes', 'night', 'sensitive', 'tape'], 'light'),
#  (['night', 'light', 'tape', 'controlsthis'], 'sensitive'),
#  (['light', 'sensitive', 'controlsthis', 'not'], 'tape'),
#  (['sensitive', 'tape', 'not', 'start'], 'controlsthis'),
#  (['tape', 'controlsthis', 'start', 'hotel'], 'not'),
#  (['controlsthis', 'not', 'hotel', 'clean'], 'start'),
#  (['not', 'start', 'clean', 'business'], 'hotel'),
#  (['start', 'hotel', 'business', 'hotel'], 'clean'),
#  (['hotel', 'clean', 'hotel', 'super'], 'business'),
#  (['clean', 'business', 'super', 'high'], 'hotel'),
#  (['business', 'hotel', 'high', 'rates'], 'super'),
#  (['hotel', 'super', 'rates', 'better'], 'high'),
#  (['super', 'high', 'better', 'chain'], 'rates'),
#  (['high', 'rates', 'chain', 'hotels'], 'better'),
#  (['rates', 'better', 'hotels', 'seattle'], 'chain'),
#  (['nice', 'rooms', 'experience', 'hotel'], 'not'),
#  (['rooms', 'not', 'hotel', 'monaco'], 'experience'),
#  (['not', 'experience', 'monaco', 'seattle'], 'hotel'),
#  (['experience', 'hotel', 'seattle', 'good'], 'monaco'),
#  (['hotel', 'monaco', 'good', 'hotel'], 'seattle'),
#  (['monaco', 'seattle', 'hotel', 'nt'], 'good'),
#  (['seattle', 'good', 'nt', 'levelpositives'], 'hotel'),
#  (['good', 'hotel', 'levelpositives', 'large'], 'nt'),
#  (['hotel', 'nt', 'large', 'bathroom'], 'levelpositives'),
#  (['nt', 'levelpositives', 'bathroom', 'mediterranean'], 'large'),
#  (['levelpositives', 'large', 'mediterranean', 'suite'], 'bathroom'),
#  (['large', 'bathroom', 'suite', 'comfortable'], 'mediterranean'),
#  (['bathroom', 'mediterranean', 'comfortable', 'bed'], 'suite'),
#  (['mediterranean', 'suite', 'bed', 'pillowsattentive'], 'comfortable'),
#  (['suite', 'comfortable', 'pillowsattentive', 'housekeeping'], 'bed'),
#  (['comfortable', 'bed', 'housekeeping', 'staffnegatives'],
#   'pillowsattentive'),
#  (['bed', 'pillowsattentive', 'staffnegatives', 'ac'], 'housekeeping'),
#  (['pillowsattentive', 'housekeeping', 'ac', 'unit'], 'staffnegatives'),
#  (['housekeeping', 'staffnegatives', 'unit', 'malfunctioned'], 'ac'),
#  (['staffnegatives', 'ac', 'malfunctioned', 'stay'], 'unit'),
#  (['ac', 'unit', 'stay', 'desk'], 'malfunctioned'),
#  (['unit', 'malfunctioned', 'desk', 'disorganized'], 'stay'),
#  (['malfunctioned', 'stay', 'disorganized', 'missed'], 'desk'),
#  (['stay', 'desk', 'missed', 'separate'], 'disorganized'),
#  (['desk', 'disorganized', 'separate', 'wakeup'], 'missed'),
#  (['disorganized', 'missed', 'wakeup', 'calls'], 'separate'),
#  (['missed', 'separate', 'calls', 'concierge'], 'wakeup'),
#  (['separate', 'wakeup', 'concierge', 'busy'], 'calls'),
#  (['wakeup', 'calls', 'busy', 'hard'], 'concierge'),
#  (['calls', 'concierge', 'hard', 'touch'], 'busy'),
#  (['concierge', 'busy', 'touch', 'did'], 'hard'),
#  (['busy', 'hard', 'did', 'nt'], 'touch'),
#  (['hard', 'touch', 'nt', 'provide'], 'did'),
#  (['touch', 'did', 'provide', 'guidance'], 'nt'),
#  (['did', 'nt', 'guidance', 'special'], 'provide'),
#  (['nt', 'provide', 'special', 'requeststv'], 'guidance'),
#  (['provide', 'guidance', 'requeststv', 'hard'], 'special'),
#  (['guidance', 'special', 'hard', 'use'], 'requeststv'),
#  (['special', 'requeststv', 'use', 'ipod'], 'hard'),
#  (['requeststv', 'hard', 'ipod', 'sound'], 'use'),
#  (['hard', 'use', 'sound', 'dock'], 'ipod'),
#  (['use', 'ipod', 'dock', 'suite'], 'sound'),
#  (['ipod', 'sound', 'suite', 'non'], 'dock'),
#  (['sound', 'dock', 'non', 'functioning'], 'suite'),
#  (['dock', 'suite', 'functioning', 'decided'], 'non'),
#  (['suite', 'non', 'decided', 'book'], 'functioning'),
#  (['non', 'functioning', 'book', 'mediterranean'], 'decided'),
#  (['functioning', 'decided', 'mediterranean', 'suite'], 'book'),
#  (['decided', 'book', 'suite', 'night'], 'mediterranean'),
#  (['book', 'mediterranean', 'night', 'weekend'], 'suite'),
#  (['mediterranean', 'suite', 'weekend', 'stay'], 'night'),
#  (['suite', 'night', 'stay', '1st'], 'weekend'),
#  (['night', 'weekend', '1st', 'choice'], 'stay'),
#  (['weekend', 'stay', 'choice', 'rest'], '1st'),
#  (['stay', '1st', 'rest', 'party'], 'choice'),
#  (['1st', 'choice', 'party', 'filled'], 'rest'),
#  (['choice', 'rest', 'filled', 'comparison'], 'party'),
#  (['rest', 'party', 'comparison', 'spent'], 'filled'),
#  (['party', 'filled', 'spent', '45'], 'comparison'),
#  (['filled', 'comparison', '45', 'night'], 'spent'),
#  (['comparison', 'spent', 'night', 'larger'], '45'),
#  (['spent', '45', 'larger', 'square'], 'night'),
#  (['45', 'night', 'square', 'footage'], 'larger'),
#  (['night', 'larger', 'footage', 'room'], 'square'),
#  (['larger', 'square', 'room', 'great'], 'footage'),
#  (['square', 'footage', 'great', 'soaking'], 'room'),
#  (['footage', 'room', 'soaking', 'tub'], 'great'),
#  (['room', 'great', 'tub', 'whirlpool'], 'soaking'),
#  (['great', 'soaking', 'whirlpool', 'jets'], 'tub'),
#  (['soaking', 'tub', 'jets', 'nice'], 'whirlpool'),
#  (['tub', 'whirlpool', 'nice', 'showerbefore'], 'jets'),
#  (['whirlpool', 'jets', 'showerbefore', 'stay'], 'nice'),
#  (['jets', 'nice', 'stay', 'hotel'], 'showerbefore'),
#  (['nice', 'showerbefore', 'hotel', 'arrange'], 'stay'),
#  (['showerbefore', 'stay', 'arrange', 'car'], 'hotel'),
#  (['stay', 'hotel', 'car', 'service'], 'arrange'),
#  (['hotel', 'arrange', 'service', 'price'], 'car'),
#  (['arrange', 'car', 'price', '53'], 'service'),
#  (['car', 'service', '53', 'tip'], 'price'),
#  (['service', 'price', 'tip', 'reasonable'], '53'),
#  (['price', '53', 'reasonable', 'driver'], 'tip'),
#  (['53', 'tip', 'driver', 'waiting'], 'reasonable'),
#  (['tip', 'reasonable', 'waiting', 'arrivalcheckin'], 'driver'),
#  (['reasonable', 'driver', 'arrivalcheckin', 'easy'], 'waiting'),
#  (['driver', 'waiting', 'easy', 'downside'], 'arrivalcheckin'),
#  (['waiting', 'arrivalcheckin', 'downside', 'room'], 'easy'),
#  (['arrivalcheckin', 'easy', 'room', 'picked'], 'downside'),
#  (['easy', 'downside', 'picked', 'person'], 'room'),
#  (['downside', 'room', 'person', 'jacuzi'], 'picked'),
#  (['room', 'picked', 'jacuzi', 'tub'], 'person'),
#  (['picked', 'person', 'tub', 'no'], 'jacuzi'),
#  (['person', 'jacuzi', 'no', 'bath'], 'tub'),
#  (['jacuzi', 'tub', 'bath', 'accessories'], 'no'),
#  (['tub', 'no', 'accessories', 'salts'], 'bath'),
#  (['no', 'bath', 'salts', 'bubble'], 'accessories'),
#  (['bath', 'accessories', 'bubble', 'bath'], 'salts'),
#  (['accessories', 'salts', 'bath', 'did'], 'bubble'),
#  (['salts', 'bubble', 'did', 'nt'], 'bath'),
#  (['bubble', 'bath', 'nt', 'stay'], 'did'),
#  (['bath', 'did', 'stay', 'night'], 'nt'),
#  (['did', 'nt', 'night', 'got'], 'stay'),
#  (['nt', 'stay', 'got', '121a'], 'night'),
#  (['stay', 'night', '121a', 'checked'], 'got'),
#  (['night', 'got', 'checked', 'voucher'], '121a'),
#  (['got', '121a', 'voucher', 'bottle'], 'checked'),
#  (['121a', 'checked', 'bottle', 'champagne'], 'voucher'),
#  (['checked', 'voucher', 'champagne', 'nice'], 'bottle'),
#  (['voucher', 'bottle', 'nice', 'gesture'], 'champagne'),
#  (['bottle', 'champagne', 'gesture', 'fish'], 'nice'),
#  (['champagne', 'nice', 'fish', 'waiting'], 'gesture'),
#  (['nice', 'gesture', 'waiting', 'room'], 'fish'),
#  (['gesture', 'fish', 'room', 'impression'], 'waiting'),
#  (['fish', 'waiting', 'impression', 'room'], 'room'),
#  (['waiting', 'room', 'room', 'huge'], 'impression'),
#  (['room', 'impression', 'huge', 'open'], 'room'),
#  (['impression', 'room', 'open', 'space'], 'huge'),
#  (['room', 'huge', 'space', 'felt'], 'open'),
#  (['huge', 'open', 'felt', 'room'], 'space'),
#  (['open', 'space', 'room', 'big'], 'felt'),
#  (['space', 'felt', 'big', 'tv'], 'room'),
#  (['felt', 'room', 'tv', 'far'], 'big'),
#  (['room', 'big', 'far', 'away'], 'tv'),
#  (['big', 'tv', 'away', 'bed'], 'far'),
#  (['tv', 'far', 'bed', 'chore'], 'away'),
#  (['far', 'away', 'chore', 'change'], 'bed'),
#  (['away', 'bed', 'change', 'channel'], 'chore'),
#  (['bed', 'chore', 'channel', 'ipod'], 'change'),
#  (['chore', 'change', 'ipod', 'dock'], 'channel'),
#  (['change', 'channel', 'dock', 'broken'], 'ipod'),
#  (['channel', 'ipod', 'broken', 'disappointingin'], 'dock'),
#  (['ipod', 'dock', 'disappointingin', 'morning'], 'broken'),
#  (['dock', 'broken', 'morning', 'way'], 'disappointingin'),
#  (['broken', 'disappointingin', 'way', 'asked'], 'morning'),
#  (['disappointingin', 'morning', 'asked', 'desk'], 'way'),
#  (['morning', 'way', 'desk', 'check'], 'asked'),
#  (['way', 'asked', 'check', 'thermostat'], 'desk'),
#  (['asked', 'desk', 'thermostat', 'said'], 'check'),
#  (['desk', 'check', 'said', '65f'], 'thermostat'),
#  (['check', 'thermostat', '65f', '74'], 'said'),
#  (['thermostat', 'said', '74', 'degrees'], '65f'),
#  (['said', '65f', 'degrees', 'warm'], '74'),
#  (['65f', '74', 'warm', 'try'], 'degrees'),
#  (['74', 'degrees', 'try', 'cover'], 'warm'),
#  (['degrees', 'warm', 'cover', 'face'], 'try'),
#  (['warm', 'try', 'face', 'night'], 'cover'),
#  (['try', 'cover', 'night', 'bright'], 'face'),
#  (['cover', 'face', 'bright', 'blue'], 'night'),
#  (['face', 'night', 'blue', 'light'], 'bright'),
#  (['night', 'bright', 'light', 'kept'], 'blue'),
#  (['bright', 'blue', 'kept', 'got'], 'light'),
#  (['blue', 'light', 'got', 'room'], 'kept'),
#  (['light', 'kept', 'room', 'night'], 'got'),
#  (['kept', 'got', 'night', 'no'], 'room'),
#  (['got', 'room', 'no', '1st'], 'night'),
#  (['room', 'night', '1st', 'drop'], 'no'),
#  (['night', 'no', 'drop', 'desk'], '1st'),
#  (['no', '1st', 'desk', 'called'], 'drop'),
#  (['1st', 'drop', 'called', 'maintainence'], 'desk'),
#  (['drop', 'desk', 'maintainence', 'came'], 'called'),
#  (['desk', 'called', 'came', 'look'], 'maintainence'),
#  (['called', 'maintainence', 'look', 'thermostat'], 'came'),
#  (['maintainence', 'came', 'thermostat', 'told'], 'look'),
#  (['came', 'look', 'told', 'play'], 'thermostat'),
#  (['look', 'thermostat', 'play', 'settings'], 'told'),
#  (['thermostat', 'told', 'settings', 'happy'], 'play'),
#  (['told', 'play', 'happy', 'digital'], 'settings'),
#  (['play', 'settings', 'digital', 'box'], 'happy'),
#  (['settings', 'happy', 'box', 'wo'], 'digital'),
#  (['happy', 'digital', 'wo', 'nt'], 'box'),
#  (['digital', 'box', 'nt', 'work'], 'wo'),
#  (['box', 'wo', 'work', 'asked'], 'nt'),
#  (['wo', 'nt', 'asked', 'wakeup'], 'work'),
#  (['nt', 'work', 'wakeup', '10am'], 'asked'),
#  (['work', 'asked', '10am', 'morning'], 'wakeup'),
#  (['asked', 'wakeup', 'morning', 'did'], '10am'),
#  (['wakeup', '10am', 'did', 'nt'], 'morning'),
#  (['10am', 'morning', 'nt', 'happen'], 'did'),
#  (['morning', 'did', 'happen', 'called'], 'nt'),
#  (['did', 'nt', 'called', 'later'], 'happen'),
#  (['nt', 'happen', 'later', '6pm'], 'called'),
#  (['happen', 'called', '6pm', 'nap'], 'later'),
#  (['called', 'later', 'nap', 'wakeup'], '6pm'),
#  (['later', '6pm', 'wakeup', 'forgot'], 'nap'),
#  (['6pm', 'nap', 'forgot', '10am'], 'wakeup'),
#  (['nap', 'wakeup', '10am', 'wakeup'], 'forgot'),
#  (['wakeup', 'forgot', 'wakeup', 'morning'], '10am'),
#  (['forgot', '10am', 'morning', 'yep'], 'wakeup'),
#  (['10am', 'wakeup', 'yep', 'forgottenthe'], 'morning'),
#  (['wakeup', 'morning', 'forgottenthe', 'bathroom'], 'yep'),
#  (['morning', 'yep', 'bathroom', 'facilities'], 'forgottenthe'),
#  (['yep', 'forgottenthe', 'facilities', 'great'], 'bathroom'),
#  (['forgottenthe', 'bathroom', 'great', 'room'], 'facilities'),
#  (['bathroom', 'facilities', 'room', 'surprised'], 'great'),
#  (['facilities', 'great', 'surprised', 'room'], 'room'),
#  (['great', 'room', 'room', 'sold'], 'surprised'),
#  (['room', 'surprised', 'sold', 'whirlpool'], 'room'),
#  (['surprised', 'room', 'whirlpool', 'bath'], 'sold'),
#  (['room', 'sold', 'bath', 'tub'], 'whirlpool'),
#  (['sold', 'whirlpool', 'tub', 'nt'], 'bath'),
#  (['whirlpool', 'bath', 'nt', 'bath'], 'tub'),
#  (['bath', 'tub', 'bath', 'amenities'], 'nt'),
#  (['tub', 'nt', 'amenities', 'great'], 'bath'),
#  (['nt', 'bath', 'great', 'relax'], 'amenities'),
#  (['bath', 'amenities', 'relax', 'water'], 'great'),
#  (['amenities', 'great', 'water', 'jets'], 'relax'),
#  (['great', 'relax', 'jets', 'going'], 'water'),
#  (['unique', 'great', 'wonderful', 'time'], 'stay'),
#  (['great', 'stay', 'time', 'hotel'], 'wonderful'),
#  (['stay', 'wonderful', 'hotel', 'monaco'], 'time'),
#  (['wonderful', 'time', 'monaco', 'location'], 'hotel'),
#  (['time', 'hotel', 'location', 'excellent'], 'monaco'),
#  (['hotel', 'monaco', 'excellent', 'short'], 'location'),
#  (['monaco', 'location', 'short', 'stroll'], 'excellent'),
#  (['location', 'excellent', 'stroll', 'main'], 'short'),
#  (['excellent', 'short', 'main', 'downtown'], 'stroll'),
#  (['short', 'stroll', 'downtown', 'shopping'], 'main'),
#  (['stroll', 'main', 'shopping', 'area'], 'downtown'),
#  (['main', 'downtown', 'area', 'pet'], 'shopping'),
#  (['downtown', 'shopping', 'pet', 'friendly'], 'area'),
#  (['shopping', 'area', 'friendly', 'room'], 'pet'),
#  (['area', 'pet', 'room', 'showed'], 'friendly'),
#  (['pet', 'friendly', 'showed', 'no'], 'room'),
#  (['friendly', 'room', 'no', 'signs'], 'showed'),
#  (['room', 'showed', 'signs', 'animal'], 'no'),
#  (['showed', 'no', 'animal', 'hair'], 'signs'),
#  (['no', 'signs', 'hair', 'smells'], 'animal'),
#  (['signs', 'animal', 'smells', 'monaco'], 'hair'),
#  (['animal', 'hair', 'monaco', 'suite'], 'smells'),
#  (['hair', 'smells', 'suite', 'sleeping'], 'monaco'),
#  (['smells', 'monaco', 'sleeping', 'area'], 'suite'),
#  (['monaco', 'suite', 'area', 'big'], 'sleeping'),
#  (['suite', 'sleeping', 'big', 'striped'], 'area'),
#  (['sleeping', 'area', 'striped', 'curtains'], 'big'),
#  (['area', 'big', 'curtains', 'pulled'], 'striped'),
#  (['big', 'striped', 'pulled', 'closed'], 'curtains'),
#  (['striped', 'curtains', 'closed', 'nice'], 'pulled'),
#  (['curtains', 'pulled', 'nice', 'touch'], 'closed'),
#  (['pulled', 'closed', 'touch', 'felt'], 'nice'),
#  (['closed', 'nice', 'felt', 'cosy'], 'touch'),
#  (['nice', 'touch', 'cosy', 'goldfish'], 'felt'),
#  (['touch', 'felt', 'goldfish', 'named'], 'cosy'),
#  (['felt', 'cosy', 'named', 'brandi'], 'goldfish'),
#  (['cosy', 'goldfish', 'brandi', 'enjoyed'], 'named'),
#  (['goldfish', 'named', 'enjoyed', 'did'], 'brandi'),
#  (['named', 'brandi', 'did', 'nt'], 'enjoyed'),
#  (['brandi', 'enjoyed', 'nt', 'partake'], 'did'),
#  (['enjoyed', 'did', 'partake', 'free'], 'nt'),
#  (['did', 'nt', 'free', 'wine'], 'partake'),
#  (['nt', 'partake', 'wine', 'coffeetea'], 'free'),
#  (['partake', 'free', 'coffeetea', 'service'], 'wine'),
#  (['free', 'wine', 'service', 'lobby'], 'coffeetea'),
#  (['wine', 'coffeetea', 'lobby', 'thought'], 'service'),
#  (['coffeetea', 'service', 'thought', 'great'], 'lobby'),
#  (['service', 'lobby', 'great', 'feature'], 'thought'),
#  (['lobby', 'thought', 'feature', 'great'], 'great'),
#  (['thought', 'great', 'great', 'staff'], 'feature'),
#  (['great', 'feature', 'staff', 'friendly'], 'great'),
#  (['feature', 'great', 'friendly', 'free'], 'staff'),
#  (['great', 'staff', 'free', 'wireless'], 'friendly'),
#  (['staff', 'friendly', 'wireless', 'internet'], 'free'),
#  (['friendly', 'free', 'internet', 'hotel'], 'wireless'),
#  (['free', 'wireless', 'hotel', 'worked'], 'internet'),
#  (['wireless', 'internet', 'worked', 'suite'], 'hotel'),
#  (['internet', 'hotel', 'suite', 'laptops'], 'worked'),
#  (['hotel', 'worked', 'laptops', 'decor'], 'suite'),
#  (['worked', 'suite', 'decor', 'lovely'], 'laptops'),
#  (['suite', 'laptops', 'lovely', 'eclectic'], 'decor'),
#  (['laptops', 'decor', 'eclectic', 'mix'], 'lovely'),
#  (['decor', 'lovely', 'mix', 'pattens'], 'eclectic'),
#  (['lovely', 'eclectic', 'pattens', 'color'], 'mix'),
#  (['eclectic', 'mix', 'color', 'palatte'], 'pattens'),
#  (['mix', 'pattens', 'palatte', 'animal'], 'color'),
#  (['pattens', 'color', 'animal', 'print'], 'palatte'),
#  (['color', 'palatte', 'print', 'bathrobes'], 'animal'),
#  (['palatte', 'animal', 'bathrobes', 'feel'], 'print'),
#  (['animal', 'print', 'feel', 'like'], 'bathrobes'),
#  (['print', 'bathrobes', 'like', 'rock'], 'feel'),
#  (['bathrobes', 'feel', 'rock', 'stars'], 'like'),
#  (['feel', 'like', 'stars', 'nice'], 'rock'),
#  (['like', 'rock', 'nice', 'did'], 'stars'),
#  (['rock', 'stars', 'did', 'nt'], 'nice'),
#  (['stars', 'nice', 'nt', 'look'], 'did'),
#  (['nice', 'did', 'look', 'like'], 'nt'),
#  (['did', 'nt', 'like', 'sterile'], 'look'),
#  (['nt', 'look', 'sterile', 'chain'], 'like'),
#  (['look', 'like', 'chain', 'hotel'], 'sterile'),
#  (['like', 'sterile', 'hotel', 'hotel'], 'chain'),
#  (['sterile', 'chain', 'hotel', 'personality'], 'hotel'),
#  (['chain', 'hotel', 'personality', 'excellent'], 'hotel'),
#  (['hotel', 'hotel', 'excellent', 'stay'], 'personality'),
#  (['great', 'stay', 'stay', 'went'], 'great'),
#  (['stay', 'great', 'went', 'seahawk'], 'stay'),
#  (['great', 'stay', 'seahawk', 'game'], 'went'),
#  (['stay', 'went', 'game', 'awesome'], 'seahawk'),
#  (['went', 'seahawk', 'awesome', 'downfall'], 'game'),
#  (['seahawk', 'game', 'downfall', 'view'], 'awesome'),
#  (['game', 'awesome', 'view', 'building'], 'downfall'),
#  (['awesome', 'downfall', 'building', 'did'], 'view'),
#  (['downfall', 'view', 'did', 'nt'], 'building'),
#  (['view', 'building', 'nt', 'complain'], 'did'),
#  (['building', 'did', 'complain', 'room'], 'nt'),
#  (['did', 'nt', 'room', 'huge'], 'complain'),
#  (['nt', 'complain', 'huge', 'staff'], 'room'),
#  (['complain', 'room', 'staff', 'helpful'], 'huge'),
#  (['room', 'huge', 'helpful', 'booked'], 'staff'),
#  (['huge', 'staff', 'booked', 'hotels'], 'helpful'),
#  (['staff', 'helpful', 'hotels', 'website'], 'booked'),
#  (['helpful', 'booked', 'website', 'seahawk'], 'hotels'),
#  (['booked', 'hotels', 'seahawk', 'package'], 'website'),
#  (['hotels', 'website', 'package', 'no'], 'seahawk'),
#  (['website', 'seahawk', 'no', 'charge'], 'package'),
#  (['seahawk', 'package', 'charge', 'parking'], 'no'),
#  (['package', 'no', 'parking', 'got'], 'charge'),
#  (['no', 'charge', 'got', 'voucher'], 'parking'),
#  (['charge', 'parking', 'voucher', 'taxi'], 'got'),
#  (['parking', 'got', 'taxi', 'problem'], 'voucher'),
#  (['got', 'voucher', 'problem', 'taxi'], 'taxi'),
#  (['voucher', 'taxi', 'taxi', 'driver'], 'problem'),
#  (['taxi', 'problem', 'driver', 'did'], 'taxi'),
#  (['problem', 'taxi', 'did', 'nt'], 'driver'),
#  (['taxi', 'driver', 'nt', 'want'], 'did'),
#  (['driver', 'did', 'want', 'accept'], 'nt'),
#  (['did', 'nt', 'accept', 'voucher'], 'want'),
#  (['nt', 'want', 'voucher', 'barely'], 'accept'),
#  (['want', 'accept', 'barely', 'spoke'], 'voucher'),
#  (['accept', 'voucher', 'spoke', 'english'], 'barely'),
#  (['voucher', 'barely', 'english', 'funny'], 'spoke'),
#  (['barely', 'spoke', 'funny', 'thing'], 'english'),
#  (['spoke', 'english', 'thing', 'speak'], 'funny'),
#  (['english', 'funny', 'speak', 'arabic'], 'thing'),
#  (['funny', 'thing', 'arabic', 'called'], 'speak'),
#  (['thing', 'speak', 'called', 'started'], 'arabic'),
#  (['speak', 'arabic', 'started', 'making'], 'called'),
#  (['arabic', 'called', 'making', 'comments'], 'started'),
#  (['called', 'started', 'comments', 'girlfriend'], 'making'),
#  (['started', 'making', 'girlfriend', 'cell'], 'comments'),
#  (['making', 'comments', 'cell', 'phone'], 'girlfriend'),
#  (['comments', 'girlfriend', 'phone', 'buddy'], 'cell'),
#  (['girlfriend', 'cell', 'buddy', 'took'], 'phone'),
#  (['cell', 'phone', 'took', 'second'], 'buddy'),
#  (['phone', 'buddy', 'second', 'realize'], 'took'),
#  (['buddy', 'took', 'realize', 'just'], 'second'),
#  (['took', 'second', 'just', 'said'], 'realize'),
#  (['second', 'realize', 'said', 'fact'], 'just'),
#  (['realize', 'just', 'fact', 'speak'], 'said'),
#  (['just', 'said', 'speak', 'language'], 'fact'),
#  (['said', 'fact', 'language', 'face'], 'speak'),
#  (['fact', 'speak', 'face', 'priceless'], 'language'),
#  (['speak', 'language', 'priceless', 'ass'], 'face'),
#  (['language', 'face', 'ass', 'told'], 'priceless'),
#  (['face', 'priceless', 'told', 'said'], 'ass'),
#  (['priceless', 'ass', 'said', 'large'], 'told'),
#  (['ass', 'told', 'large', 'city'], 'said'),
#  (['told', 'said', 'city', 'told'], 'large'),
#  (['said', 'large', 'told', 'head'], 'city'),
#  (['large', 'city', 'head', 'doorman'], 'told'),
#  (['city', 'told', 'doorman', 'issue'], 'head'),
#  (['told', 'head', 'issue', 'called'], 'doorman'),
#  (['head', 'doorman', 'called', 'cab'], 'issue'),
#  (['doorman', 'issue', 'cab', 'company'], 'called'),
#  (['issue', 'called', 'company', 'promply'], 'cab'),
#  (['called', 'cab', 'promply', 'answer'], 'company'),
#  (['cab', 'company', 'answer', 'did'], 'promply'),
#  (['company', 'promply', 'did', 'nt'], 'answer'),
#  (['promply', 'answer', 'nt', 'apologized'], 'did'),
#  (['answer', 'did', 'apologized', 'offered'], 'nt'),
#  (['did', 'nt', 'offered', 'pay'], 'apologized'),
#  (['nt', 'apologized', 'pay', 'taxi'], 'offered'),
#  (['apologized', 'offered', 'taxi', 'bucks'], 'pay'),
#  (['offered', 'pay', 'bucks', 'miles'], 'taxi'),
#  (['pay', 'taxi', 'miles', 'stadium'], 'bucks'),
#  (['taxi', 'bucks', 'stadium', 'game'], 'miles'),
#  (['bucks', 'miles', 'game', 'plan'], 'stadium'),
#  (['miles', 'stadium', 'plan', 'taxi'], 'game'),
#  (['stadium', 'game', 'taxi', 'return'], 'plan'),
#  (['game', 'plan', 'return', 'going'], 'taxi'),
#  (['plan', 'taxi', 'going', 'humpin'], 'return'),
#  (['taxi', 'return', 'humpin', 'great'], 'going'),
#  (['return', 'going', 'great', 'walk'], 'humpin'),
#  (['going', 'humpin', 'walk', 'did'], 'great'),
#  (['humpin', 'great', 'did', 'nt'], 'walk'),
#  (['great', 'walk', 'nt', 'mind'], 'did'),
#  (['walk', 'did', 'mind', 'right'], 'nt'),
#  (['did', 'nt', 'right', 'christmas'], 'mind'),
#  (['nt', 'mind', 'christmas', 'wonderful'], 'right'),
#  (['mind', 'right', 'wonderful', 'lights'], 'christmas'),
#  (['right', 'christmas', 'lights', 'homeless'], 'wonderful'),
#  (['christmas', 'wonderful', 'homeless', 'stowed'], 'lights'),
#  (['wonderful', 'lights', 'stowed', 'away'], 'homeless'),
#  (['lights', 'homeless', 'away', 'building'], 'stowed'),
#  (['homeless', 'stowed', 'building', 'entrances'], 'away'),
#  (['stowed', 'away', 'entrances', 'leave'], 'building'),
#  (['away', 'building', 'leave', 'police'], 'entrances'),
#  (['building', 'entrances', 'police', 'presence'], 'leave'),
#  (['entrances', 'leave', 'presence', 'not'], 'police'),
#  (['leave', 'police', 'not', 'greatest'], 'presence'),
#  (['police', 'presence', 'greatest', 'area'], 'not'),
#  (['presence', 'not', 'area', 'stadium'], 'greatest'),
#  (['not', 'greatest', 'stadium', 'activities'], 'area'),
#  (['greatest', 'area', 'activities', 'blocks'], 'stadium'),
#  (['area', 'stadium', 'blocks', 'pike'], 'activities'),
#  (['stadium', 'activities', 'pike', 'street'], 'blocks'),
#  (['activities', 'blocks', 'street', 'waterfront'], 'pike'),
#  (['blocks', 'pike', 'waterfront', 'great'], 'street'),
#  (['pike', 'street', 'great', 'coffee'], 'waterfront'),
#  (['street', 'waterfront', 'coffee', 'shops'], 'great'),
#  (['waterfront', 'great', 'shops', 'way'], 'coffee'),
#  (['great', 'coffee', 'way', 'hotel'], 'shops'),
#  (['coffee', 'shops', 'hotel', 'mantained'], 'way'),
#  (['shops', 'way', 'mantained', 'foyer'], 'hotel'),
#  (['way', 'hotel', 'foyer', 'awesome'], 'mantained'),
#  (['hotel', 'mantained', 'awesome', 'wine'], 'foyer'),
#  (['mantained', 'foyer', 'wine', 'tasting'], 'awesome'),
#  (['foyer', 'awesome', 'tasting', 'available'], 'wine'),
#  (['awesome', 'wine', 'available', 'evening'], 'tasting'),
#  (['wine', 'tasting', 'evening', 'best'], 'available'),
#  (['tasting', 'available', 'best', 'dog'], 'evening'),
#  (['available', 'evening', 'dog', 'taking'], 'best'),
#  (['evening', 'best', 'taking', 'st'], 'dog'),
#  (['best', 'dog', 'st', 'bernard'], 'taking'),
#  (['dog', 'taking', 'bernard', 'time'], 'st'),
#  (['taking', 'st', 'time', 'family'], 'bernard'),
#  (['st', 'bernard', 'family', 'safes'], 'time'),
#  (['bernard', 'time', 'safes', 'hotel'], 'family'),
#  (['time', 'family', 'hotel', 'located'], 'safes'),
#  (['family', 'safes', 'located', 'service'], 'hotel'),
#  (['safes', 'hotel', 'service', 'desk'], 'located'),
#  (['hotel', 'located', 'desk', 'room'], 'service'),
#  (['located', 'service', 'room', 'bathroom'], 'desk'),
#  (['service', 'desk', 'bathroom', 'huge'], 'room'),
#  (['desk', 'room', 'huge', 'jetted'], 'bathroom'),
#  (['room', 'bathroom', 'jetted', 'tub'], 'huge'),
#  (['bathroom', 'huge', 'tub', 'huge'], 'jetted'),
#  (['huge', 'jetted', 'huge', 'funny'], 'tub'),
#  (['jetted', 'tub', 'funny', 'house'], 'huge'),
#  (['tub', 'huge', 'house', 'keeping'], 'funny'),
#  (['huge', 'funny', 'keeping', 'walked'], 'house'),
#  (['funny', 'house', 'walked', 'girlfriend'], 'keeping'),
#  (['house', 'keeping', 'girlfriend', 'getting'], 'walked'),
#  (['keeping', 'walked', 'getting', 'dressed'], 'girlfriend'),
#  (['walked', 'girlfriend', 'dressed', 'did'], 'getting'),
#  (['girlfriend', 'getting', 'did', 'nt'], 'dressed'),
#  (['getting', 'dressed', 'nt', 'hear'], 'did'),
#  (['dressed', 'did', 'hear', 'knock'], 'nt'),
#  (['did', 'nt', 'knock', 'doing'], 'hear'),
#  (['nt', 'hear', 'doing', 'turn'], 'knock'),
#  (['hear', 'knock', 'turn', 'service'], 'doing'),
#  (['knock', 'doing', 'service', 'screamed'], 'turn'),
#  (['doing', 'turn', 'screamed', 'girlfriend'], 'service'),
#  (['turn', 'service', 'girlfriend', 'screams'], 'screamed'),
#  (['service', 'screamed', 'screams', 'hit'], 'girlfriend'),
#  (['screamed', 'girlfriend', 'hit', 'floor'], 'screams'),
#  (['girlfriend', 'screams', 'floor', 'laughing'], 'hit'),
#  (['screams', 'hit', 'laughing', 'started'], 'floor'),
#  (['hit', 'floor', 'started', 'talking'], 'laughing'),
#  (['floor', 'laughing', 'talking', 'spanish'], 'started'),
#  (['laughing', 'started', 'spanish', 'worked'], 'talking'),
#  (['started', 'talking', 'worked', 'place'], 'spanish'),
#  (['talking', 'spanish', 'place', 'recommend'], 'worked'),
#  (['spanish', 'worked', 'recommend', 'price'], 'place'),
#  (['worked', 'place', 'price', 'check'], 'recommend'),
#  (['place', 'recommend', 'check', 'online'], 'price'),
#  (['recommend', 'price', 'online', 'deals'], 'check'),
#  (['price', 'check', 'deals', 'just'], 'online'),
#  (['check', 'online', 'just', 'good'], 'deals'),
#  (['online', 'deals', 'good', 'not'], 'just'),
#  (['deals', 'just', 'not', 'better'], 'good'),
#  (['just', 'good', 'better', 'besite'], 'not'),
#  (['good', 'not', 'besite', 'contains'], 'better'),
#  (['not', 'better', 'contains', 'deals'], 'besite'),
#  (['better', 'besite', 'deals', 'vouchers'], 'contains'),
#  (['besite', 'contains', 'vouchers', 'travel'], 'deals'),
#  (['contains', 'deals', 'travel', 'websites'], 'vouchers'),
#  (['deals', 'vouchers', 'websites', 'nt'], 'travel'),
#  (['vouchers', 'travel', 'nt', 'tell'], 'websites'),
#  (['love', 'monaco', 'husband', 'stayed'], 'staff'),
#  (['monaco', 'staff', 'stayed', 'hotel'], 'husband'),
#  (['staff', 'husband', 'hotel', 'crazy'], 'stayed'),
#  (['husband', 'stayed', 'crazy', 'weekend'], 'hotel'),
#  (['stayed', 'hotel', 'weekend', 'attending'], 'crazy'),
#  (['hotel', 'crazy', 'attending', 'memorial'], 'weekend'),
#  (['crazy', 'weekend', 'memorial', 'service'], 'attending'),
#  (['weekend', 'attending', 'service', 'best'], 'memorial'),
#  (['attending', 'memorial', 'best', 'friend'], 'service'),
#  (['memorial', 'service', 'friend', 'husband'], 'best'),
#  (['service', 'best', 'husband', 'celebrating'], 'friend'),
#  (['best', 'friend', 'celebrating', '12th'], 'husband'),
#  (['friend', 'husband', '12th', 'wedding'], 'celebrating'),
#  (['husband', 'celebrating', 'wedding', 'anniversary'], '12th'),
#  (['celebrating', '12th', 'anniversary', 'talk'], 'wedding'),
#  (['12th', 'wedding', 'talk', 'mixed'], 'anniversary'),
#  (['wedding', 'anniversary', 'mixed', 'emotions'], 'talk'),
#  (['anniversary', 'talk', 'emotions', 'booked'], 'mixed'),
#  (['talk', 'mixed', 'booked', 'suite'], 'emotions'),
#  (['mixed', 'emotions', 'suite', 'hotel'], 'booked'),
#  (['emotions', 'booked', 'hotel', 'monte'], 'suite'),
#  (['booked', 'suite', 'monte', 'carlos'], 'hotel'),
#  (['suite', 'hotel', 'carlos', 'loaned'], 'monte'),
#  (['hotel', 'monte', 'loaned', 'beautiful'], 'carlos'),
#  (['monte', 'carlos', 'beautiful', 'fantanned'], 'loaned'),
#  (['carlos', 'loaned', 'fantanned', 'goldfish'], 'beautiful'),
#  (['loaned', 'beautiful', 'goldfish', 'named'], 'fantanned'),
#  (['beautiful', 'fantanned', 'named', 'joliet'], 'goldfish'),
#  (['fantanned', 'goldfish', 'joliet', 'weekend'], 'named'),
#  (['goldfish', 'named', 'weekend', 'visited'], 'joliet'),
#  (['named', 'joliet', 'visited', 'dogs'], 'weekend'),
#  (['joliet', 'weekend', 'dogs', 'worked'], 'visited'),
#  (['weekend', 'visited', 'worked', 'desk'], 'dogs'),
#  (['visited', 'dogs', 'desk', 'human'], 'worked'),
#  (['dogs', 'worked', 'human', 'companions'], 'desk'),
#  (['worked', 'desk', 'companions', 'room'], 'human'),
#  (['desk', 'human', 'room', 'decorated'], 'companions'),
#  (['human', 'companions', 'decorated', 'nicely'], 'room'),
#  (['companions', 'room', 'nicely', 'couch'], 'decorated'),
#  (['room', 'decorated', 'couch', 'used'], 'nicely'),
#  (['decorated', 'nicely', 'used', 'pillows'], 'couch'),
#  (['nicely', 'couch', 'pillows', 'loccitane'], 'used'),
#  (['couch', 'used', 'loccitane', 'bath'], 'pillows'),
#  (['used', 'pillows', 'bath', 'amenities'], 'loccitane'),
#  (['pillows', 'loccitane', 'amenities', 'welcome'], 'bath'),
#  (['loccitane', 'bath', 'welcome', 'sight'], 'amenities'),
#  (['bath', 'amenities', 'sight', 'room'], 'welcome'),
#  (['amenities', 'welcome', 'room', 'quiet'], 'sight'),
#  (['welcome', 'sight', 'quiet', 'peaceful'], 'room'),
#  (['sight', 'room', 'peaceful', 'wireless'], 'quiet'),
#  (['room', 'quiet', 'wireless', 'internet'], 'peaceful'),
#  (['quiet', 'peaceful', 'internet', 'access'], 'wireless'),
#  (['peaceful', 'wireless', 'access', 'wonderful'], 'internet'),
#  (['wireless', 'internet', 'wonderful', 'server'], 'access'),
#  (['internet', 'access', 'server', 'went'], 'wonderful'),
#  (['access', 'wonderful', 'went', 'morning'], 'server'),
#  (['wonderful', 'server', 'morning', 'leaving'], 'went'),
#  (['server', 'went', 'leaving', 'problems'], 'morning'),
#  (['went', 'morning', 'problems', 'printing'], 'leaving'),
#  (['morning', 'leaving', 'printing', 'boarding'], 'problems'),
#  (['leaving', 'problems', 'boarding', 'passes'], 'printing'),
#  (['problems', 'printing', 'passes', 'afternoon'], 'boarding'),
#  (['printing', 'boarding', 'afternoon', 'reception'], 'passes'),
#  (['boarding', 'passes', 'reception', 'serves'], 'afternoon'),
#  (['passes', 'afternoon', 'serves', 'oenophilesatisfying'], 'reception'),
#  (['afternoon', 'reception', 'oenophilesatisfying', 'wine'], 'serves'),
#  (['reception', 'serves', 'wine', 'australia'], 'oenophilesatisfying'),
#  (['serves', 'oenophilesatisfying', 'australia', 'scrumptious'], 'wine'),
#  (['oenophilesatisfying', 'wine', 'scrumptious', 'cookies'], 'australia'),
#  (['wine', 'australia', 'cookies', 'restaurant'], 'scrumptious'),
#  (['australia', 'scrumptious', 'restaurant', 'closed'], 'cookies'),
#  (['scrumptious', 'cookies', 'closed', 'renovation'], 'restaurant'),
#  (['cookies', 'restaurant', 'renovation', 'stay'], 'closed'),
#  (['restaurant', 'closed', 'stay', 'finally'], 'renovation'),
#  (['closed', 'renovation', 'finally', 'ate'], 'stay'),
#  (['renovation', 'stay', 'ate', 'food'], 'finally'),
#  (['stay', 'finally', 'food', 'good'], 'ate'),
#  (['finally', 'ate', 'good', 'drinks'], 'food'),
#  (['ate', 'food', 'drinks', 'better'], 'good'),
#  (['food', 'good', 'better', 'word'], 'drinks'),
#  (['good', 'drinks', 'word', 'caution'], 'better'),
#  (['drinks', 'better', 'caution', 'restaurant'], 'word'),
#  (['better', 'word', 'restaurant', 'larger'], 'caution'),
#  (['word', 'caution', 'larger', 'person'], 'restaurant'),
#  (['caution', 'restaurant', 'person', 'not'], 'larger'),
#  (['restaurant', 'larger', 'not', 'sit'], 'person'),
#  (['larger', 'person', 'sit', 'booths'], 'not'),
#  (['person', 'not', 'booths', 'wo'], 'sit'),
#  (['not', 'sit', 'wo', 'nt'], 'booths'),
#  (['sit', 'booths', 'nt', 'fit'], 'wo'),
#  (['booths', 'wo', 'fit', '56'], 'nt'),
#  (['wo', 'nt', '56', '125'], 'fit'),
#  (['nt', 'fit', '125', 'lbs'], '56'),
#  (['fit', '56', 'lbs', 'husband'], '125'),
#  (['56', '125', 'husband', '59'], 'lbs'),
#  (['125', 'lbs', '59', '175'], 'husband'),
#  (['lbs', 'husband', '175', 'table'], '59'),
#  (['husband', '59', 'table', 'smackagainst'], '175'),
#  (['59', '175', 'smackagainst', 'stomach'], 'table'),
#  (['175', 'table', 'stomach', 'couple'], 'smackagainst'),
#  (['table', 'smackagainst', 'couple', 'inches'], 'stomach'),
#  (['smackagainst', 'stomach', 'inches', 'space'], 'couple'),
#  (['stomach', 'couple', 'space', 'mighty'], 'inches'),
#  (['couple', 'inches', 'mighty', 'uncomfortable'], 'space'),
#  (['inches', 'space', 'uncomfortable', 'patron'], 'mighty'),
#  (['space', 'mighty', 'patron', 'larger'], 'uncomfortable'),
#  (['mighty', 'uncomfortable', 'larger', 'pregnant'], 'patron'),
#  (['uncomfortable', 'patron', 'pregnant', 'bad'], 'larger'),
#  (['patron', 'larger', 'bad', 'design'], 'pregnant'),
#  (['larger', 'pregnant', 'design', 'opinion'], 'bad'),
#  (['pregnant', 'bad', 'opinion', 'place'], 'design'),
#  (['bad', 'design', 'place', 'decorated'], 'opinion'),
#  (['design', 'opinion', 'decorated', 'funky'], 'place'),
#  (['opinion', 'place', 'funky', 'welcoming'], 'decorated'),
#  (['place', 'decorated', 'welcoming', 'way'], 'funky'),
#  (['decorated', 'funky', 'way', 'metal'], 'welcoming'),
#  (['funky', 'welcoming', 'metal', 'wood'], 'way'),
#  (['welcoming', 'way', 'wood', 'handblown'], 'metal'),
#  (['way', 'metal', 'handblown', 'glass'], 'wood'),
#  (['metal', 'wood', 'glass', 'light'], 'handblown'),
#  (['wood', 'handblown', 'light', 'fixtures'], 'glass'),
#  (['handblown', 'glass', 'fixtures', 'expect'], 'light'),
#  (['glass', 'light', 'expect', 'seattle'], 'fixtures'),
#  (['light', 'fixtures', 'seattle', 'capital'], 'expect'),
#  (['fixtures', 'expect', 'capital', 'glass'], 'seattle'),
#  (['expect', 'seattle', 'glass', 'art'], 'capital'),
#  (['seattle', 'capital', 'art', 'industry'], 'glass'),
#  (['capital', 'glass', 'industry', 'definitely'], 'art'),
#  (['glass', 'art', 'definitely', 'stay'], 'industry'),
#  (['art', 'industry', 'stay', 'reason'], 'definitely'),
#  (['cozy', 'stay', 'city', 'husband'], 'rainy'),
#  (['stay', 'rainy', 'husband', 'spent'], 'city'),
#  (['rainy', 'city', 'spent', 'nights'], 'husband'),
#  (['city', 'husband', 'nights', 'monaco'], 'spent'),
#  (['husband', 'spent', 'monaco', 'early'], 'nights'),
#  (['spent', 'nights', 'early', 'january'], 'monaco'),
#  (['nights', 'monaco', 'january', '2008'], 'early'),
#  (['monaco', 'early', '2008', 'business'], 'january'),
#  (['early', 'january', 'business', 'trip'], '2008'),
#  (['january', '2008', 'trip', 'chance'], 'business'),
#  (['2008', 'business', 'chance', 'come'], 'trip'),
#  (['business', 'trip', 'come', 'ridewe'], 'chance'),
#  (['trip', 'chance', 'ridewe', 'booked'], 'come'),
#  (['chance', 'come', 'booked', 'monte'], 'ridewe'),
#  (['come', 'ridewe', 'monte', 'carlo'], 'booked'),
#  (['ridewe', 'booked', 'carlo', 'suite'], 'monte'),
#  (['booked', 'monte', 'suite', 'proved'], 'carlo'),
#  (['monte', 'carlo', 'proved', 'comfortable'], 'suite'),
#  (['carlo', 'suite', 'comfortable', 'longish'], 'proved'),
#  (['suite', 'proved', 'longish', 'stay'], 'comfortable'),
#  (['proved', 'comfortable', 'stay', 'room'], 'longish'),
#  (['comfortable', 'longish', 'room', '905'], 'stay'),
#  (['longish', 'stay', '905', 'located'], 'room'),
#  (['stay', 'room', 'located', 'street'], '905'),
#  (['room', '905', 'street', 'building'], 'located'),
#  (['905', 'located', 'building', 'street'], 'street'),
#  (['located', 'street', 'street', 'noise'], 'building'),
#  (['street', 'building', 'noise', 'not'], 'street'),
#  (['building', 'street', 'not', 'problem'], 'noise'),
#  (['street', 'noise', 'problem', 'view'], 'not'),
#  (['noise', 'not', 'view', 'interesting'], 'problem'),
#  (['not', 'problem', 'interesting', 'rooms'], 'view'),
#  (['problem', 'view', 'rooms', 'building'], 'interesting'),
#  (['view', 'interesting', 'building', 'look'], 'rooms'),
#  (['interesting', 'rooms', 'look', 'dank'], 'building'),
#  (['rooms', 'building', 'dank', 'alley'], 'look'),
#  (['building', 'look', 'alley', 'midsection'], 'dank'),
#  (['look', 'dank', 'midsection', 'large'], 'alley'),
#  (['dank', 'alley', 'large', 'office'], 'midsection'),
#  (['alley', 'midsection', 'office', 'building'], 'large'),
#  (['midsection', 'large', 'building', 'suite'], 'office'),
#  (['large', 'office', 'suite', 'comfortable'], 'building'),
#  (['office', 'building', 'comfortable', 'plenty'], 'suite'),
#  (['building', 'suite', 'plenty', 'room'], 'comfortable'),
#  (['suite', 'comfortable', 'room', 'spread'], 'plenty'),
#  (['comfortable', 'plenty', 'spread', 'bathroom'], 'room'),
#  (['plenty', 'room', 'bathroom', 'attractive'], 'spread'),
#  (['room', 'spread', 'attractive', 'squeaky'], 'bathroom'),
#  (['spread', 'bathroom', 'squeaky', 'clean'], 'attractive'),
#  (['bathroom', 'attractive', 'clean', 'small'], 'squeaky'),
#  (['attractive', 'squeaky', 'small', 'comparison'], 'clean'),
#  (['squeaky', 'clean', 'comparison', 'generous'], 'small'),
#  (['clean', 'small', 'generous', 'proportions'], 'comparison'),
#  (['small', 'comparison', 'proportions', 'sitting'], 'generous'),
#  (['comparison', 'generous', 'sitting', 'sleeping'], 'proportions'),
#  (['generous', 'proportions', 'sleeping', 'areas'], 'sitting'),
#  (['proportions', 'sitting', 'areas', 'lots'], 'sleeping'),
#  (['sitting', 'sleeping', 'lots', 'comfortable'], 'areas'),
#  (['sleeping', 'areas', 'comfortable', 'seating'], 'lots'),
#  (['areas', 'lots', 'seating', 'options'], 'comfortable'),
#  (['lots', 'comfortable', 'options', 'good'], 'seating'),
#  (['comfortable', 'seating', 'good', 'lighting'], 'options'),
#  (['seating', 'options', 'lighting', 'plenty'], 'good'),
#  (['options', 'good', 'plenty', 'storage'], 'lighting'),
#  (['good', 'lighting', 'storage', 'clothing'], 'plenty'),
#  (['lighting', 'plenty', 'clothing', 'luggage'], 'storage'),
#  (['plenty', 'storage', 'luggage', 'hotel'], 'clothing'),
#  (['storage', 'clothing', 'hotel', 'staff'], 'luggage'),
#  (['clothing', 'luggage', 'staff', 'friendly'], 'hotel'),
#  (['luggage', 'hotel', 'friendly', 'efficient'], 'staff'),
#  (['hotel', 'staff', 'efficient', 'housekeeping'], 'friendly'),
#  ...]

# %%
word_to_ix = my_data.word_to_ix
ix_to_word = my_data.ix_to_word

# %%
len(my_data.context_dataset)
# Out:
# 2032672

# %%
# create Dataset class for transforming out dataset
# takes the loaded data and transforms it into a Dataset object to pass to the dataloader
# we could also include the import here but we will not

class CBOW_Dataset(Dataset):
    
    def __init__(self, full_data):
        self.data = full_data
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        x = make_context_vector(self.data[idx][0], word_to_ix)
        y = torch.tensor(word_to_ix[self.data[idx][1]], dtype=torch.long)
        return x, y

# %%
class CBOW(nn.Module):

    def __init__(self, vocab_size, embedding_size, batch_size):
        
        super().__init__()
        self.batch_size = batch_size
        self.embedding_size = embedding_size
        self.embedding = nn.Embedding(num_embeddings=vocab_size,
                                     embedding_dim=embedding_size)
        self.fc1 = nn.Linear(in_features=embedding_size,
                            out_features=vocab_size)

    def forward(self, inputs):
        x_embedded = sum(self.embedding(inputs).view(4, self.batch_size, self.embedding_size))
        y_out = self.fc1(x_embedded)
        m = nn.LogSoftmax()
        y_out = m(y_out)
        return y_out

# %% [markdown]
# ### Let's try and train this model

# %%
# set the batch size here
BATCH_SIZE = 2048
EMBEDDING_SIZE = 50
data_loader = CBOW_Dataset(my_data.context_dataset)
data_loader = DataLoader(data_loader, batch_size = BATCH_SIZE, drop_last=True)

# %%
import torch.optim as optim
vocab_size = len(my_data.word_to_ix)
model = CBOW(vocab_size, embedding_size=EMBEDDING_SIZE, batch_size=BATCH_SIZE)
loss_func = torch.nn.NLLLoss()
lr = 0.001
optimizer = optim.Adam(model.parameters(), lr=lr)

num_epochs = 10

# %%
# train loop
num_batches = len(data_loader)

for epoch in range(1, num_epochs+1):
    for i, d in enumerate(data_loader):
        optimizer.zero_grad()
        x, y = d
        y_pred = model(x)        
        loss = loss_func(y_pred, y)
        loss_batch = loss.item()
        loss.backward()
        optimizer.step()
        print(f'Epoch [{epoch}/{num_epochs}], batch: [{i}/{num_batches}, loss: {loss_batch:.4f}]')
# Out:
# C:\Users\Damja\AppData\Local\Temp\ipykernel_21116\2173844042.py:17: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   y_out = m(y_out)
# Epoch [1/2], batch: [0/993, loss: 11.9325]
# Epoch [1/2], batch: [1/993, loss: 11.9569]
# Epoch [1/2], batch: [2/993, loss: 11.9584]
# Epoch [1/2], batch: [3/993, loss: 11.9193]
# Epoch [1/2], batch: [4/993, loss: 11.9034]
# Epoch [1/2], batch: [5/993, loss: 11.8822]
# Epoch [1/2], batch: [6/993, loss: 11.8552]
# Epoch [1/2], batch: [7/993, loss: 11.8495]
# Epoch [1/2], batch: [8/993, loss: 11.8650]
# Epoch [1/2], batch: [9/993, loss: 11.7946]
# Epoch [1/2], batch: [10/993, loss: 11.8412]
# Epoch [1/2], batch: [11/993, loss: 11.8232]
# Epoch [1/2], batch: [12/993, loss: 11.7485]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [354], in <cell line: 4>()
#       9 loss = loss_func(y_pred, y)
#      10 loss_batch = loss.item()
# ---> 11 loss.backward()
#      12 optimizer.step()
#      13 print(f'Epoch [{epoch}/{num_epochs}], batch: [{i}/{num_batches}, loss: {loss_batch:.4f}]')
#
# File ~\anaconda3\lib\site-packages\torch\_tensor.py:307, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     298 if has_torch_function_unary(self):
#     299     return handle_torch_function(
#     300         Tensor.backward,
#     301         (self,),
#    (...)
#     305         create_graph=create_graph,
#     306         inputs=inputs)
# --> 307 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~\anaconda3\lib\site-packages\torch\autograd\__init__.py:154, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     151 if retain_graph is None:
#     152     retain_graph = create_graph
# --> 154 Variable._execution_engine.run_backward(
#     155     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
from collections import Counter
target_words = [elem[1] for elem in my_data.context_dataset]
counts = Counter(target_words)

sorted_counts = counts.most_common()
lower_30 = sorted_counts[-76030: -76000 ]
upper_30 = sorted_counts[:30]

# %%
upper_30

# %%
lower_30

# %%
model.eval()

word_list = ["manage", "occupied", "passport", "improve", "hotel", "good", "stayed", "staff", "friendly"]
w_as_ix = [torch.tensor(word_to_ix[word_list[i]], dtype=torch.long).to(device) for i in range(len(word_list))]
embedded_words = [model.embedding(elem) for elem in w_as_ix]

cos = nn.CosineSimilarity()

# %%
result_dist = [0 for elem in word_list]
result_words = [None for elem in word_list]

with torch.no_grad():
  for w, ix in word_to_ix.items():  # loop through whole vocab
    cur_embed = model.embedding((torch.tensor(ix, dtype=torch.long)).to(device))  # embedding for the current word in our vocabulary
    for idx, embed in enumerate(embedded_words):  # enumerate to always know which word we're looking at
      if w != word_list[idx]:  # check that we don't compare the same word with itself, otherwise the cosine dist will be always 1
        cur_dist = cos(cur_embed.view(1, 50), embed.view(1,50))
        if cur_dist > result_dist[idx]:
          result_dist[idx] = cur_dist
          result_words[idx] = w

# %%
res_comparison = [ (f'Actual word: "{word_list[idx]}"', f'Most Similar Word: "{result_words[idx]}"') for idx in range(len(word_list))]

res_comparison

# %%
import torch.nn as nn

def get_closest_word(word, topn=5):
  word_distance = []
  emb = model.embedding
  pdist = nn.PairwiseDistance()
  i = word_to_ix[word]
  lookup_tensor_i = torch.tensor([i], dtype=torch.long).to(device)
  v_i = emb(lookup_tensor_i).to(device)
  for j in range(len(word_to_ix)):
    if j != i:
      lookup_tensor_j = torch.tensor([j], dtype=torch.long).to(device)
      v_j = emb(lookup_tensor_j)
      word_distance.append((ix_to_word[j], float(pdist(v_i, v_j))))
  word_distance.sort(key=lambda x: x[1])
  return word_distance[:topn]
